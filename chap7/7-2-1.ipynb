# %%
import torch
import torchtext
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
import time

# %%
start=time.time()

TEXT = torchtext.data.Field(sequential = True, batch_first = True, lower = True)
LABEL = torchtext.data.Field(sequential = False, batch_first = True) 

from torchtext import datasets
train_data, test_data = datasets.IMDB.splits(TEXT, LABEL)
train_data, valid_data = train_data.split(split_ratio = 0.8)

TEXT.build_vocab(train_data, max_size=10000, min_freq=10, vectors=None)
LABEL.build_vocab(train_data)

BATCH_SIZE = 100
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
train_iterator, valid_iterator, test_iterator = torchtext.data.BucketIterator.splits(
    (train_data, valid_data, test_data), 
    batch_size = BATCH_SIZE,
    device = device)

# %%
vocab_size = len(TEXT.vocab)
n_classes = 2

# %%
class BasicRNN(nn.Module):
    def __init__(self, n_layers, hidden_dim, n_vocab, embed_dim, n_classes, dropout_p = 0.2):
        super(BasicRNN, self).__init__()
        self.n_layers = n_layers 
        self.embed = nn.Embedding(n_vocab, embed_dim) 
        self.hidden_dim = hidden_dim
        self.dropout = nn.Dropout(dropout_p)
        self.rnn = nn.RNN(embed_dim, self.hidden_dim, num_layers = self.n_layers, batch_first = True) 
        self.out = nn.Linear(self.hidden_dim, n_classes) 

    def forward(self, x):
        x = self.embed(x) 
        h_0 = self._init_state(batch_size = x.size(0)) 
        x, _ = self.rnn(x, h_0) 
        h_t = x[:, -1, :] 
        self.dropout(h_t)
        logit = torch.sigmoid(self.out(h_t))
        return logit

    def _init_state(self, batch_size = 1):
        weight = next(self.parameters()).data 
        return weight.new(self.n_layers, batch_size, self.hidden_dim).zero_()

# %%
model = BasicRNN(n_layers = 1, hidden_dim = 256, n_vocab = vocab_size, embed_dim = 128, n_classes = n_classes, dropout_p = 0.5)
model.to(device)

loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)

# %%
def train(model, optimizer, train_iter):
    model.train()
    for b, batch in enumerate(train_iter):
        x, y = batch.text.to(device), batch.label.to(device)
        y.data.sub_(1)
        optimizer.zero_grad()

        logit = model(x)
        loss = F.cross_entropy(logit, y)
        loss.backward()
        optimizer.step()

        if b % 50 == 0:
            print("Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}".format(e,b * len(x),
                                                                           len(train_iter.dataset),
                                                                           100. * b / len(train_iter),
                                                                           loss.item()))

# %%
def evaluate(model, val_iter):
    model.eval()
    corrects, total, total_loss = 0, 0, 0

    for batch in val_iter:
        x, y = batch.text.to(device), batch.label.to(device)
        y.data.sub_(1) 
        logit = model(x)
        loss = F.cross_entropy(logit, y, reduction = "sum")
        total += y.size(0)
        total_loss += loss.item()
        corrects += (logit.max(1)[1].view(y.size()).data == y.data).sum()
        
    avg_loss = total_loss / len(val_iter.dataset)
    avg_accuracy = corrects / total
    return avg_loss, avg_accuracy

# %%
BATCH_SIZE = 100
LR = 0.001
EPOCHS = 30
for e in range(1, EPOCHS + 1):
    train(model, optimizer, train_iterator)
    val_loss, val_accuracy = evaluate(model, valid_iterator)
    print("[EPOCH: %d], Validation Loss: %5.2f | Validation Accuracy: %5.2f" % (e, val_loss, val_accuracy))
# Out:
# Train Epoch: 1 [0/20000 (0%)]	Loss: 0.691958
# Train Epoch: 1 [5000/20000 (25%)]	Loss: 0.693959
# Train Epoch: 1 [10000/20000 (50%)]	Loss: 0.695409
# Train Epoch: 1 [15000/20000 (75%)]	Loss: 0.693281
# [EPOCH: 1], Validation Loss:  0.69 | Validation Accuracy:  0.50
# Train Epoch: 2 [0/20000 (0%)]	Loss: 0.692825
# Train Epoch: 2 [5000/20000 (25%)]	Loss: 0.698675
# Train Epoch: 2 [10000/20000 (50%)]	Loss: 0.691628
# Train Epoch: 2 [15000/20000 (75%)]	Loss: 0.692554
# [EPOCH: 2], Validation Loss:  0.69 | Validation Accuracy:  0.50
# Train Epoch: 3 [0/20000 (0%)]	Loss: 0.690710
# Train Epoch: 3 [5000/20000 (25%)]	Loss: 0.697846
# Train Epoch: 3 [10000/20000 (50%)]	Loss: 0.691458
# Train Epoch: 3 [15000/20000 (75%)]	Loss: 0.686122
# [EPOCH: 3], Validation Loss:  0.69 | Validation Accuracy:  0.50
# Train Epoch: 4 [0/20000 (0%)]	Loss: 0.692657
# Train Epoch: 4 [5000/20000 (25%)]	Loss: 0.691477
# Train Epoch: 4 [10000/20000 (50%)]	Loss: 0.693330
# Train Epoch: 4 [15000/20000 (75%)]	Loss: 0.694684
# [EPOCH: 4], Validation Loss:  0.69 | Validation Accuracy:  0.50
# Train Epoch: 5 [0/20000 (0%)]	Loss: 0.692335
# Train Epoch: 5 [5000/20000 (25%)]	Loss: 0.693084
# Train Epoch: 5 [10000/20000 (50%)]	Loss: 0.690971
# Train Epoch: 5 [15000/20000 (75%)]	Loss: 0.693374
# [EPOCH: 5], Validation Loss:  0.69 | Validation Accuracy:  0.51
# Train Epoch: 6 [0/20000 (0%)]	Loss: 0.693779
# Train Epoch: 6 [5000/20000 (25%)]	Loss: 0.691592
# Train Epoch: 6 [10000/20000 (50%)]	Loss: 0.692493
# Train Epoch: 6 [15000/20000 (75%)]	Loss: 0.694427
# [EPOCH: 6], Validation Loss:  0.69 | Validation Accuracy:  0.51
# Train Epoch: 7 [0/20000 (0%)]	Loss: 0.686236
# Train Epoch: 7 [5000/20000 (25%)]	Loss: 0.693472
# Train Epoch: 7 [10000/20000 (50%)]	Loss: 0.693423
# Train Epoch: 7 [15000/20000 (75%)]	Loss: 0.694007
# [EPOCH: 7], Validation Loss:  0.69 | Validation Accuracy:  0.51
# Train Epoch: 8 [0/20000 (0%)]	Loss: 0.690629
# Train Epoch: 8 [5000/20000 (25%)]	Loss: 0.692430
# Train Epoch: 8 [10000/20000 (50%)]	Loss: 0.692014
# Train Epoch: 8 [15000/20000 (75%)]	Loss: 0.692850
# [EPOCH: 8], Validation Loss:  0.69 | Validation Accuracy:  0.49
# Train Epoch: 9 [0/20000 (0%)]	Loss: 0.692777
# Train Epoch: 9 [5000/20000 (25%)]	Loss: 0.692659
# Train Epoch: 9 [10000/20000 (50%)]	Loss: 0.694001
# Train Epoch: 9 [15000/20000 (75%)]	Loss: 0.693730
# [EPOCH: 9], Validation Loss:  0.69 | Validation Accuracy:  0.49
# Train Epoch: 10 [0/20000 (0%)]	Loss: 0.690931
# Train Epoch: 10 [5000/20000 (25%)]	Loss: 0.692679
# Train Epoch: 10 [10000/20000 (50%)]	Loss: 0.691331
# Train Epoch: 10 [15000/20000 (75%)]	Loss: 0.692435
# [EPOCH: 10], Validation Loss:  0.70 | Validation Accuracy:  0.49
# Train Epoch: 11 [0/20000 (0%)]	Loss: 0.694467
# Train Epoch: 11 [5000/20000 (25%)]	Loss: 0.690596
# Train Epoch: 11 [10000/20000 (50%)]	Loss: 0.694628
# Train Epoch: 11 [15000/20000 (75%)]	Loss: 0.691126
# [EPOCH: 11], Validation Loss:  0.70 | Validation Accuracy:  0.49
# Train Epoch: 12 [0/20000 (0%)]	Loss: 0.691152
# Train Epoch: 12 [5000/20000 (25%)]	Loss: 0.692809
# Train Epoch: 12 [10000/20000 (50%)]	Loss: 0.694749
# Train Epoch: 12 [15000/20000 (75%)]	Loss: 0.690957
# [EPOCH: 12], Validation Loss:  0.70 | Validation Accuracy:  0.50
# Train Epoch: 13 [0/20000 (0%)]	Loss: 0.693275
# Train Epoch: 13 [5000/20000 (25%)]	Loss: 0.693550
# Train Epoch: 13 [10000/20000 (50%)]	Loss: 0.692526
# Train Epoch: 13 [15000/20000 (75%)]	Loss: 0.692405
# [EPOCH: 13], Validation Loss:  0.70 | Validation Accuracy:  0.50
# Train Epoch: 14 [0/20000 (0%)]	Loss: 0.692045
# Train Epoch: 14 [5000/20000 (25%)]	Loss: 0.690254
# Train Epoch: 14 [10000/20000 (50%)]	Loss: 0.697186
# Train Epoch: 14 [15000/20000 (75%)]	Loss: 0.690575
# [EPOCH: 14], Validation Loss:  0.70 | Validation Accuracy:  0.50
# Train Epoch: 15 [0/20000 (0%)]	Loss: 0.693815
# Train Epoch: 15 [5000/20000 (25%)]	Loss: 0.690352
# Train Epoch: 15 [10000/20000 (50%)]	Loss: 0.690015
# Train Epoch: 15 [15000/20000 (75%)]	Loss: 0.696858
# [EPOCH: 15], Validation Loss:  0.70 | Validation Accuracy:  0.50
# Train Epoch: 16 [0/20000 (0%)]	Loss: 0.690864
# Train Epoch: 16 [5000/20000 (25%)]	Loss: 0.690320
# Train Epoch: 16 [10000/20000 (50%)]	Loss: 0.690104
# Train Epoch: 16 [15000/20000 (75%)]	Loss: 0.693367
# [EPOCH: 16], Validation Loss:  0.70 | Validation Accuracy:  0.50
# Train Epoch: 17 [0/20000 (0%)]	Loss: 0.692897
# Train Epoch: 17 [5000/20000 (25%)]	Loss: 0.693111
# Train Epoch: 17 [10000/20000 (50%)]	Loss: 0.691032
# Train Epoch: 17 [15000/20000 (75%)]	Loss: 0.697808
# [EPOCH: 17], Validation Loss:  0.70 | Validation Accuracy:  0.50
# Train Epoch: 18 [0/20000 (0%)]	Loss: 0.701084
# Train Epoch: 18 [5000/20000 (25%)]	Loss: 0.690068
# Train Epoch: 18 [10000/20000 (50%)]	Loss: 0.688453
# Train Epoch: 18 [15000/20000 (75%)]	Loss: 0.690084
# [EPOCH: 18], Validation Loss:  0.70 | Validation Accuracy:  0.49
# Train Epoch: 19 [0/20000 (0%)]	Loss: 0.690590
# Train Epoch: 19 [5000/20000 (25%)]	Loss: 0.689774
# Train Epoch: 19 [10000/20000 (50%)]	Loss: 0.689740
# Train Epoch: 19 [15000/20000 (75%)]	Loss: 0.689753
# [EPOCH: 19], Validation Loss:  0.71 | Validation Accuracy:  0.49
# Train Epoch: 20 [0/20000 (0%)]	Loss: 0.692166
# Train Epoch: 20 [5000/20000 (25%)]	Loss: 0.689325
# Train Epoch: 20 [10000/20000 (50%)]	Loss: 0.689593
# Train Epoch: 20 [15000/20000 (75%)]	Loss: 0.689667
# [EPOCH: 20], Validation Loss:  0.70 | Validation Accuracy:  0.49
# Train Epoch: 21 [0/20000 (0%)]	Loss: 0.689633
# Train Epoch: 21 [5000/20000 (25%)]	Loss: 0.697180
# Train Epoch: 21 [10000/20000 (50%)]	Loss: 0.698246
# Train Epoch: 21 [15000/20000 (75%)]	Loss: 0.690018
# [EPOCH: 21], Validation Loss:  0.71 | Validation Accuracy:  0.49
# Train Epoch: 22 [0/20000 (0%)]	Loss: 0.689366
# Train Epoch: 22 [5000/20000 (25%)]	Loss: 0.690278
# Train Epoch: 22 [10000/20000 (50%)]	Loss: 0.689731
# Train Epoch: 22 [15000/20000 (75%)]	Loss: 0.689570
# [EPOCH: 22], Validation Loss:  0.71 | Validation Accuracy:  0.49
# Train Epoch: 23 [0/20000 (0%)]	Loss: 0.689154
# Train Epoch: 23 [5000/20000 (25%)]	Loss: 0.690119
# Train Epoch: 23 [10000/20000 (50%)]	Loss: 0.689889
# Train Epoch: 23 [15000/20000 (75%)]	Loss: 0.689450
# [EPOCH: 23], Validation Loss:  0.71 | Validation Accuracy:  0.49
# Train Epoch: 24 [0/20000 (0%)]	Loss: 0.696921
# Train Epoch: 24 [5000/20000 (25%)]	Loss: 0.697036
# Train Epoch: 24 [10000/20000 (50%)]	Loss: 0.689532
# Train Epoch: 24 [15000/20000 (75%)]	Loss: 0.689522
# [EPOCH: 24], Validation Loss:  0.71 | Validation Accuracy:  0.51
# Train Epoch: 25 [0/20000 (0%)]	Loss: 0.689978
# Train Epoch: 25 [5000/20000 (25%)]	Loss: 0.690372
# Train Epoch: 25 [10000/20000 (50%)]	Loss: 0.689509
# Train Epoch: 25 [15000/20000 (75%)]	Loss: 0.689618
# [EPOCH: 25], Validation Loss:  0.71 | Validation Accuracy:  0.50
# Train Epoch: 26 [0/20000 (0%)]	Loss: 0.689379
# Train Epoch: 26 [5000/20000 (25%)]	Loss: 0.689620
# Train Epoch: 26 [10000/20000 (50%)]	Loss: 0.688341
# Train Epoch: 26 [15000/20000 (75%)]	Loss: 0.690384
# [EPOCH: 26], Validation Loss:  0.71 | Validation Accuracy:  0.50
# Train Epoch: 27 [0/20000 (0%)]	Loss: 0.689852
# Train Epoch: 27 [5000/20000 (25%)]	Loss: 0.689597
# Train Epoch: 27 [10000/20000 (50%)]	Loss: 0.689740
# Train Epoch: 27 [15000/20000 (75%)]	Loss: 0.689383
# [EPOCH: 27], Validation Loss:  0.71 | Validation Accuracy:  0.49
# Train Epoch: 28 [0/20000 (0%)]	Loss: 0.689551
# Train Epoch: 28 [5000/20000 (25%)]	Loss: 0.690143
# Train Epoch: 28 [10000/20000 (50%)]	Loss: 0.689971
# Train Epoch: 28 [15000/20000 (75%)]	Loss: 0.691303
# [EPOCH: 28], Validation Loss:  0.71 | Validation Accuracy:  0.49
# Train Epoch: 29 [0/20000 (0%)]	Loss: 0.689371
# Train Epoch: 29 [5000/20000 (25%)]	Loss: 0.689507
# Train Epoch: 29 [10000/20000 (50%)]	Loss: 0.689680
# Train Epoch: 29 [15000/20000 (75%)]	Loss: 0.689472
# [EPOCH: 29], Validation Loss:  0.71 | Validation Accuracy:  0.51
# Train Epoch: 30 [0/20000 (0%)]	Loss: 0.689405
# Train Epoch: 30 [5000/20000 (25%)]	Loss: 0.689265
# Train Epoch: 30 [10000/20000 (50%)]	Loss: 0.689680
# Train Epoch: 30 [15000/20000 (75%)]	Loss: 0.689319
# [EPOCH: 30], Validation Loss:  0.71 | Validation Accuracy:  0.50

# %%
test_loss, test_acc = evaluate(model,test_iterator)
print("Test Loss: %5.2f | Test Accuracy: %5.2f" % (test_loss, test_acc))
# Out:
# Test Loss:  0.72 | Test Accuracy:  0.51
